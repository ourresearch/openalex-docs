# %%
import os
import re
from pathlib import Path
import requests

# %%
entity_endpoints = [
    'works',
    'authors',
    'sources',
    'publishers',
    'funders',
    'institutions',
    'concepts',
]

# %% [markdown]
# ### From API

# %%
api_valid_fields = []
for e in entity_endpoints:
    r = requests.get(f"https://api.openalex.org/{e}/valid_fields")
    for item in r.json():
        api_valid_fields.append({
            'key': item,
            'entityType': e,
        })

# %%
len(api_valid_fields)
# Out:
# 287

# %%
api_valid_fields
# Out:
# [{'key': 'abstract.search', 'entityType': 'works'},
#  {'key': 'apc_list.currency', 'entityType': 'works'},
#  {'key': 'apc_list.provenance', 'entityType': 'works'},
#  {'key': 'apc_list.value', 'entityType': 'works'},
#  {'key': 'apc_list.value_usd', 'entityType': 'works'},
#  {'key': 'apc_paid.currency', 'entityType': 'works'},
#  {'key': 'apc_paid.provenance', 'entityType': 'works'},
#  {'key': 'apc_paid.value', 'entityType': 'works'},
#  {'key': 'apc_paid.value_usd', 'entityType': 'works'},
#  {'key': 'author.id', 'entityType': 'works'},
#  {'key': 'author.orcid', 'entityType': 'works'},
#  {'key': 'authors_count', 'entityType': 'works'},
#  {'key': 'authorships.author.id', 'entityType': 'works'},
#  {'key': 'authorships.author.orcid', 'entityType': 'works'},
#  {'key': 'authorships.countries', 'entityType': 'works'},
#  {'key': 'authorships.institutions.continent', 'entityType': 'works'},
#  {'key': 'authorships.institutions.country_code', 'entityType': 'works'},
#  {'key': 'authorships.institutions.id', 'entityType': 'works'},
#  {'key': 'authorships.institutions.is_global_south', 'entityType': 'works'},
#  {'key': 'authorships.institutions.lineage', 'entityType': 'works'},
#  {'key': 'authorships.institutions.ror', 'entityType': 'works'},
#  {'key': 'authorships.institutions.type', 'entityType': 'works'},
#  {'key': 'authorships.is_corresponding', 'entityType': 'works'},
#  {'key': 'best_oa_location.is_accepted', 'entityType': 'works'},
#  {'key': 'best_oa_location.is_oa', 'entityType': 'works'},
#  {'key': 'best_oa_location.is_published', 'entityType': 'works'},
#  {'key': 'best_oa_location.license', 'entityType': 'works'},
#  {'key': 'best_oa_location.source.host_organization', 'entityType': 'works'},
#  {'key': 'best_oa_location.source.host_organization_lineage',
#   'entityType': 'works'},
#  {'key': 'best_oa_location.source.id', 'entityType': 'works'},
#  {'key': 'best_oa_location.source.is_in_doaj', 'entityType': 'works'},
#  {'key': 'best_oa_location.source.is_oa', 'entityType': 'works'},
#  {'key': 'best_oa_location.source.issn', 'entityType': 'works'},
#  {'key': 'best_oa_location.source.type', 'entityType': 'works'},
#  {'key': 'best_oa_location.version', 'entityType': 'works'},
#  {'key': 'best_open_version', 'entityType': 'works'},
#  {'key': 'cited_by', 'entityType': 'works'},
#  {'key': 'cited_by_count', 'entityType': 'works'},
#  {'key': 'cites', 'entityType': 'works'},
#  {'key': 'concept.id', 'entityType': 'works'},
#  {'key': 'concepts.id', 'entityType': 'works'},
#  {'key': 'concepts.wikidata', 'entityType': 'works'},
#  {'key': 'concepts_count', 'entityType': 'works'},
#  {'key': 'corresponding_author_ids', 'entityType': 'works'},
#  {'key': 'corresponding_institution_ids', 'entityType': 'works'},
#  {'key': 'countries_distinct_count', 'entityType': 'works'},
#  {'key': 'default.search', 'entityType': 'works'},
#  {'key': 'display_name', 'entityType': 'works'},
#  {'key': 'display_name.search', 'entityType': 'works'},
#  {'key': 'doi', 'entityType': 'works'},
#  {'key': 'doi_starts_with', 'entityType': 'works'},
#  {'key': 'from_created_date', 'entityType': 'works'},
#  {'key': 'from_publication_date', 'entityType': 'works'},
#  {'key': 'fulltext.search', 'entityType': 'works'},
#  {'key': 'grants.award_id', 'entityType': 'works'},
#  {'key': 'grants.funder', 'entityType': 'works'},
#  {'key': 'has_abstract', 'entityType': 'works'},
#  {'key': 'has_doi', 'entityType': 'works'},
#  {'key': 'has_fulltext', 'entityType': 'works'},
#  {'key': 'has_ngrams', 'entityType': 'works'},
#  {'key': 'has_oa_accepted_or_published_version', 'entityType': 'works'},
#  {'key': 'has_oa_submitted_version', 'entityType': 'works'},
#  {'key': 'has_old_authors', 'entityType': 'works'},
#  {'key': 'has_orcid', 'entityType': 'works'},
#  {'key': 'has_pdf_url', 'entityType': 'works'},
#  {'key': 'has_pmcid', 'entityType': 'works'},
#  {'key': 'has_pmid', 'entityType': 'works'},
#  {'key': 'has_raw_affiliation_string', 'entityType': 'works'},
#  {'key': 'has_references', 'entityType': 'works'},
#  {'key': 'host_venue.id', 'entityType': 'works'},
#  {'key': 'host_venue.publisher', 'entityType': 'works'},
#  {'key': 'ids.mag', 'entityType': 'works'},
#  {'key': 'ids.openalex', 'entityType': 'works'},
#  {'key': 'ids.pmcid', 'entityType': 'works'},
#  {'key': 'ids.pmid', 'entityType': 'works'},
#  {'key': 'institution.id', 'entityType': 'works'},
#  {'key': 'institutions.continent', 'entityType': 'works'},
#  {'key': 'institutions.country_code', 'entityType': 'works'},
#  {'key': 'institutions.id', 'entityType': 'works'},
#  {'key': 'institutions.is_global_south', 'entityType': 'works'},
#  {'key': 'institutions.ror', 'entityType': 'works'},
#  {'key': 'institutions.type', 'entityType': 'works'},
#  {'key': 'institutions_distinct_count', 'entityType': 'works'},
#  {'key': 'is_corresponding', 'entityType': 'works'},
#  {'key': 'is_oa', 'entityType': 'works'},
#  {'key': 'is_paratext', 'entityType': 'works'},
#  {'key': 'is_retracted', 'entityType': 'works'},
#  {'key': 'journal', 'entityType': 'works'},
#  {'key': 'language', 'entityType': 'works'},
#  {'key': 'locations.is_accepted', 'entityType': 'works'},
#  {'key': 'locations.is_oa', 'entityType': 'works'},
#  {'key': 'locations.is_published', 'entityType': 'works'},
#  {'key': 'locations.license', 'entityType': 'works'},
#  {'key': 'locations.source.has_issn', 'entityType': 'works'},
#  {'key': 'locations.source.host_institution_lineage', 'entityType': 'works'},
#  {'key': 'locations.source.host_organization', 'entityType': 'works'},
#  {'key': 'locations.source.host_organization_lineage', 'entityType': 'works'},
#  {'key': 'locations.source.id', 'entityType': 'works'},
#  {'key': 'locations.source.is_in_doaj', 'entityType': 'works'},
#  {'key': 'locations.source.is_oa', 'entityType': 'works'},
#  {'key': 'locations.source.issn', 'entityType': 'works'},
#  {'key': 'locations.source.publisher_lineage', 'entityType': 'works'},
#  {'key': 'locations.source.type', 'entityType': 'works'},
#  {'key': 'locations.version', 'entityType': 'works'},
#  {'key': 'locations_count', 'entityType': 'works'},
#  {'key': 'mag', 'entityType': 'works'},
#  {'key': 'oa_status', 'entityType': 'works'},
#  {'key': 'open_access.any_repository_has_fulltext', 'entityType': 'works'},
#  {'key': 'open_access.is_oa', 'entityType': 'works'},
#  {'key': 'open_access.oa_status', 'entityType': 'works'},
#  {'key': 'openalex', 'entityType': 'works'},
#  {'key': 'openalex_id', 'entityType': 'works'},
#  {'key': 'pmcid', 'entityType': 'works'},
#  {'key': 'pmid', 'entityType': 'works'},
#  {'key': 'primary_location.is_accepted', 'entityType': 'works'},
#  {'key': 'primary_location.is_oa', 'entityType': 'works'},
#  {'key': 'primary_location.is_published', 'entityType': 'works'},
#  {'key': 'primary_location.license', 'entityType': 'works'},
#  {'key': 'primary_location.source.has_issn', 'entityType': 'works'},
#  {'key': 'primary_location.source.host_institution_lineage',
#   'entityType': 'works'},
#  {'key': 'primary_location.source.host_organization', 'entityType': 'works'},
#  {'key': 'primary_location.source.host_organization_lineage',
#   'entityType': 'works'},
#  {'key': 'primary_location.source.id', 'entityType': 'works'},
#  {'key': 'primary_location.source.is_in_doaj', 'entityType': 'works'},
#  {'key': 'primary_location.source.is_oa', 'entityType': 'works'},
#  {'key': 'primary_location.source.issn', 'entityType': 'works'},
#  {'key': 'primary_location.source.publisher_lineage', 'entityType': 'works'},
#  {'key': 'primary_location.source.type', 'entityType': 'works'},
#  {'key': 'primary_location.version', 'entityType': 'works'},
#  {'key': 'publication_date', 'entityType': 'works'},
#  {'key': 'publication_year', 'entityType': 'works'},
#  {'key': 'raw_affiliation_string.search', 'entityType': 'works'},
#  {'key': 'referenced_works', 'entityType': 'works'},
#  {'key': 'referenced_works_count', 'entityType': 'works'},
#  {'key': 'related_to', 'entityType': 'works'},
#  {'key': 'repository', 'entityType': 'works'},
#  {'key': 'sustainable_development_goals.id', 'entityType': 'works'},
#  {'key': 'title.search', 'entityType': 'works'},
#  {'key': 'to_publication_date', 'entityType': 'works'},
#  {'key': 'to_updated_date', 'entityType': 'works'},
#  {'key': 'type', 'entityType': 'works'},
#  {'key': 'type_crossref', 'entityType': 'works'},
#  {'key': 'version', 'entityType': 'works'},
#  {'key': 'cited_by_count', 'entityType': 'authors'},
#  {'key': 'concept.id', 'entityType': 'authors'},
#  {'key': 'concepts.id', 'entityType': 'authors'},
#  {'key': 'default.search', 'entityType': 'authors'},
#  {'key': 'display_name', 'entityType': 'authors'},
#  {'key': 'display_name.search', 'entityType': 'authors'},
#  {'key': 'from_created_date', 'entityType': 'authors'},
#  {'key': 'has_orcid', 'entityType': 'authors'},
#  {'key': 'ids.openalex', 'entityType': 'authors'},
#  {'key': 'last_known_institution.continent', 'entityType': 'authors'},
#  {'key': 'last_known_institution.country_code', 'entityType': 'authors'},
#  {'key': 'last_known_institution.id', 'entityType': 'authors'},
#  {'key': 'last_known_institution.is_global_south', 'entityType': 'authors'},
#  {'key': 'last_known_institution.lineage', 'entityType': 'authors'},
#  {'key': 'last_known_institution.ror', 'entityType': 'authors'},
#  {'key': 'last_known_institution.type', 'entityType': 'authors'},
#  {'key': 'openalex', 'entityType': 'authors'},
#  {'key': 'openalex_id', 'entityType': 'authors'},
#  {'key': 'orcid', 'entityType': 'authors'},
#  {'key': 'scopus', 'entityType': 'authors'},
#  {'key': 'summary_stats.2yr_mean_citedness', 'entityType': 'authors'},
#  {'key': 'summary_stats.h_index', 'entityType': 'authors'},
#  {'key': 'summary_stats.i10_index', 'entityType': 'authors'},
#  {'key': 'works_count', 'entityType': 'authors'},
#  {'key': 'x_concepts.id', 'entityType': 'authors'},
#  {'key': 'apc_prices.currency', 'entityType': 'sources'},
#  {'key': 'apc_prices.price', 'entityType': 'sources'},
#  {'key': 'apc_usd', 'entityType': 'sources'},
#  {'key': 'cited_by_count', 'entityType': 'sources'},
#  {'key': 'concept.id', 'entityType': 'sources'},
#  {'key': 'concepts.id', 'entityType': 'sources'},
#  {'key': 'continent', 'entityType': 'sources'},
#  {'key': 'country_code', 'entityType': 'sources'},
#  {'key': 'default.search', 'entityType': 'sources'},
#  {'key': 'display_name', 'entityType': 'sources'},
#  {'key': 'display_name.search', 'entityType': 'sources'},
#  {'key': 'from_created_date', 'entityType': 'sources'},
#  {'key': 'has_issn', 'entityType': 'sources'},
#  {'key': 'host_organization', 'entityType': 'sources'},
#  {'key': 'host_organization.id', 'entityType': 'sources'},
#  {'key': 'host_organization_lineage', 'entityType': 'sources'},
#  {'key': 'ids.mag', 'entityType': 'sources'},
#  {'key': 'ids.openalex', 'entityType': 'sources'},
#  {'key': 'is_global_south', 'entityType': 'sources'},
#  {'key': 'is_in_doaj', 'entityType': 'sources'},
#  {'key': 'is_oa', 'entityType': 'sources'},
#  {'key': 'issn', 'entityType': 'sources'},
#  {'key': 'openalex', 'entityType': 'sources'},
#  {'key': 'openalex_id', 'entityType': 'sources'},
#  {'key': 'publisher', 'entityType': 'sources'},
#  {'key': 'summary_stats.2yr_mean_citedness', 'entityType': 'sources'},
#  {'key': 'summary_stats.h_index', 'entityType': 'sources'},
#  {'key': 'summary_stats.i10_index', 'entityType': 'sources'},
#  {'key': 'type', 'entityType': 'sources'},
#  {'key': 'works_count', 'entityType': 'sources'},
#  {'key': 'x_concepts.id', 'entityType': 'sources'},
#  {'key': 'cited_by_count', 'entityType': 'publishers'},
#  {'key': 'continent', 'entityType': 'publishers'},
#  {'key': 'country_codes', 'entityType': 'publishers'},
#  {'key': 'default.search', 'entityType': 'publishers'},
#  {'key': 'display_name', 'entityType': 'publishers'},
#  {'key': 'display_name.search', 'entityType': 'publishers'},
#  {'key': 'from_created_date', 'entityType': 'publishers'},
#  {'key': 'hierarchy_level', 'entityType': 'publishers'},
#  {'key': 'ids.openalex', 'entityType': 'publishers'},
#  {'key': 'ids.ror', 'entityType': 'publishers'},
#  {'key': 'ids.wikidata', 'entityType': 'publishers'},
#  {'key': 'lineage', 'entityType': 'publishers'},
#  {'key': 'openalex', 'entityType': 'publishers'},
#  {'key': 'openalex_id', 'entityType': 'publishers'},
#  {'key': 'parent_publisher', 'entityType': 'publishers'},
#  {'key': 'roles.id', 'entityType': 'publishers'},
#  {'key': 'ror', 'entityType': 'publishers'},
#  {'key': 'summary_stats.2yr_mean_citedness', 'entityType': 'publishers'},
#  {'key': 'summary_stats.h_index', 'entityType': 'publishers'},
#  {'key': 'summary_stats.i10_index', 'entityType': 'publishers'},
#  {'key': 'wikidata', 'entityType': 'publishers'},
#  {'key': 'works_count', 'entityType': 'publishers'},
#  {'key': 'cited_by_count', 'entityType': 'funders'},
#  {'key': 'continent', 'entityType': 'funders'},
#  {'key': 'country_code', 'entityType': 'funders'},
#  {'key': 'default.search', 'entityType': 'funders'},
#  {'key': 'description.search', 'entityType': 'funders'},
#  {'key': 'display_name', 'entityType': 'funders'},
#  {'key': 'display_name.search', 'entityType': 'funders'},
#  {'key': 'from_created_date', 'entityType': 'funders'},
#  {'key': 'grants_count', 'entityType': 'funders'},
#  {'key': 'ids.crossref', 'entityType': 'funders'},
#  {'key': 'ids.doi', 'entityType': 'funders'},
#  {'key': 'ids.openalex', 'entityType': 'funders'},
#  {'key': 'ids.ror', 'entityType': 'funders'},
#  {'key': 'ids.wikidata', 'entityType': 'funders'},
#  {'key': 'is_global_south', 'entityType': 'funders'},
#  {'key': 'openalex', 'entityType': 'funders'},
#  {'key': 'openalex_id', 'entityType': 'funders'},
#  {'key': 'roles.id', 'entityType': 'funders'},
#  {'key': 'ror', 'entityType': 'funders'},
#  {'key': 'summary_stats.2yr_mean_citedness', 'entityType': 'funders'},
#  {'key': 'summary_stats.h_index', 'entityType': 'funders'},
#  {'key': 'summary_stats.i10_index', 'entityType': 'funders'},
#  {'key': 'wikidata', 'entityType': 'funders'},
#  {'key': 'works_count', 'entityType': 'funders'},
#  {'key': 'cited_by_count', 'entityType': 'institutions'},
#  {'key': 'concept.id', 'entityType': 'institutions'},
#  {'key': 'concepts.id', 'entityType': 'institutions'},
#  {'key': 'continent', 'entityType': 'institutions'},
#  {'key': 'country_code', 'entityType': 'institutions'},
#  {'key': 'default.search', 'entityType': 'institutions'},
#  {'key': 'display_name', 'entityType': 'institutions'},
#  {'key': 'display_name.search', 'entityType': 'institutions'},
#  {'key': 'from_created_date', 'entityType': 'institutions'},
#  {'key': 'has_ror', 'entityType': 'institutions'},
#  {'key': 'ids.openalex', 'entityType': 'institutions'},
#  {'key': 'is_global_south', 'entityType': 'institutions'},
#  {'key': 'lineage', 'entityType': 'institutions'},
#  {'key': 'openalex', 'entityType': 'institutions'},
#  {'key': 'openalex_id', 'entityType': 'institutions'},
#  {'key': 'repositories.host_organization', 'entityType': 'institutions'},
#  {'key': 'repositories.host_organization_lineage',
#   'entityType': 'institutions'},
#  {'key': 'repositories.id', 'entityType': 'institutions'},
#  {'key': 'roles.id', 'entityType': 'institutions'},
#  {'key': 'ror', 'entityType': 'institutions'},
#  {'key': 'summary_stats.2yr_mean_citedness', 'entityType': 'institutions'},
#  {'key': 'summary_stats.h_index', 'entityType': 'institutions'},
#  {'key': 'summary_stats.i10_index', 'entityType': 'institutions'},
#  {'key': 'type', 'entityType': 'institutions'},
#  {'key': 'works_count', 'entityType': 'institutions'},
#  {'key': 'x_concepts.id', 'entityType': 'institutions'},
#  {'key': 'ancestors.id', 'entityType': 'concepts'},
#  {'key': 'cited_by_count', 'entityType': 'concepts'},
#  {'key': 'default.search', 'entityType': 'concepts'},
#  {'key': 'display_name', 'entityType': 'concepts'},
#  {'key': 'display_name.search', 'entityType': 'concepts'},
#  {'key': 'from_created_date', 'entityType': 'concepts'},
#  {'key': 'has_wikidata', 'entityType': 'concepts'},
#  {'key': 'ids.openalex', 'entityType': 'concepts'},
#  {'key': 'level', 'entityType': 'concepts'},
#  {'key': 'openalex', 'entityType': 'concepts'},
#  {'key': 'openalex_id', 'entityType': 'concepts'},
#  {'key': 'summary_stats.2yr_mean_citedness', 'entityType': 'concepts'},
#  {'key': 'summary_stats.h_index', 'entityType': 'concepts'},
#  {'key': 'summary_stats.i10_index', 'entityType': 'concepts'},
#  {'key': 'wikidata_id', 'entityType': 'concepts'},
#  {'key': 'works_count', 'entityType': 'concepts'}]

# %% [markdown]
# ### From GUI source code

# %%
url = "https://raw.githubusercontent.com/ourresearch/openalex-gui/search/src/facetConfigs.js"
r = requests.get(url)

# %%
p = re.compile(r'key: "(.*?)",.*?entityType: "(.*?)"', flags=re.S)  # re.S means dot matches newline
# p = re.compile(r'key: "(.*?)",', flags=re.S)  # re.S means dot matches newline
gui_matches = p.findall(r.text)

# %%
r.text
# Out:
# 'import {sortByKey} from "./util";\n\nconst facetCategories = {\n    works: [\n        "popular",\n        "author",\n        "source",\n        "funder",\n        "institution",\n\n        "open access",\n        "search",\n        "citation",\n        "other",\n    ],\n    authors: [\n        "popular",\n        "institution",\n        "geo",\n        "ids",\n        "other",\n    ],\n    sources: [\n        "popular",\n        "open access",\n        "other",\n    ],\n    publishers: [\n        "popular",\n        "other",\n    ],\n    institutions: [\n        "popular",\n        "geo",\n        "other",\n    ],\n    concepts: [\n        "popular",\n        "other"\n    ],\n}\n\nconst facetCategoriesIcons = {\n    popular: "mdi-star-outline",\n    author: "mdi-account-outline",\n    institution: "mdi-town-hall",\n    geo: "mdi-map-marker-outline",\n    funder: "mdi-cash-multiple",\n    "source": "mdi-book-multiple-outline",\n    repository: "mdi-package-variant",\n    search: "mdi-magnify",\n    "open access": "mdi-lock-open-outline",\n    apc: "mdi-cash",\n    ids: "mdi-tag-outline",\n    citation: "mdi-format-quote-close",\n    other: "mdi-dots-horizontal",\n}\n\n\nconst facetConfigs = function (entityType) {\n    const ret = [\n\n\n        // works:  WASPFIC. test\n\n        {\n            key: "ids.openalex",\n            entityType: "works",\n            entityId: "works",\n            pidPrefix: "openalex",\n            displayName: "Work",\n            isEntity: true,\n            isSingleWork: true,\n            isId: true,\n            showInSidebar: true,\n            noOptions: true,\n            type: "entity",\n            categories: ["other"],\n            icon: "mdi-file-document-outline",\n            regex: /^(?:https:\\/\\/openalex\\.org\\/)?([wW]\\d+)$/,\n        },\n        {\n            key: "doi",\n            entityType: "works",\n            entityId: "works",\n            displayName: "DOI (work)",\n            isEntity: true,\n            isSingleWork: true,\n            isId: true,\n            pidPrefix: "doi",\n            showInSidebar: true,\n            noOptions: true,\n            type: "entity",\n            categories: ["other"],\n            icon: "mdi-file-document-outline",\n            regex: /(10\\.\\d{4,9}\\/[-._;()/:A-Za-z0-9]+)/,\n        },\n        {\n            key: "concepts.id",\n            entityType: "works",\n            displayName: "Concept",\n            pidPrefix: "openalex",\n            isEntity: true,\n            showInSidebar: true,\n            entityId: "concepts",\n            autocompleteEndpoint: "autocomplete/concepts",\n            type: "select",\n            categories: ["other", ],\n            isCore: true,\n            icon: "mdi-lightbulb-outline",\n            regex: /^(?:https:\\/\\/openalex\\.org\\/)?([cC]\\d+)$/,\n        },\n        {\n            key: "grants.funder",\n            entityType: "works",\n            displayName: "Funder",\n            pidPrefix: "openalex",\n            isEntity: true,\n            showInSidebar: true,\n            entityId: "funders",\n            type: "select",\n            categories: ["funder"],\n            isCore: true,\n            icon: "mdi-cash-multiple",\n            regex: /^(?:https:\\/\\/openalex\\.org\\/)?([fF]\\d+)$/,\n        },\n        {\n            key: "grants.award_id",\n            entityType: "works",\n            displayName: "Grant ID",\n            showInSidebar: true,\n            type: "select",\n            categories: ["funder"],\n            isCore: true,\n            icon: "mdi-cash-multiple",\n        },\n\n        {\n            key: "authorships.institutions.id",\n            entityType: "works",\n            displayName: "Institution",\n            pidPrefix: "openalex",\n            isEntity: true,\n            showInSidebar: true,\n            entityId: "institutions",\n            autocompleteEndpoint: "autocomplete/institutions",\n            type: "select",\n         ...

# %%
gui_filters = []
for key, entity_type in gui_matches:
    gui_filters.append({
        'key': key,
        'entityType': entity_type,
    })

# %%
len(gui_filters)
# Out:
# 74

# %%
import pandas as pd
import numpy as np

# %%
pd.Series([x in api_valid_fields for x in gui_filters]).value_counts()
# Out:
# True    74
# Name: count, dtype: int64

# %%
pd.DataFrame(gui_filters).to_csv('gui_filters.csv', index=False)

# %% [markdown]
# ### From docs

# %%
docs_txt = {}
for e in entity_endpoints:
    fp = list(Path('../../').rglob(f'filter-{e}.md'))[0]
    txt = fp.read_text()
    docs_txt[fp.name] = txt

# %%
docs_txt.keys()
# Out:
# dict_keys(['filter-works.md', 'filter-authors.md', 'filter-sources.md', 'filter-publishers.md', 'filter-funders.md', 'filter-institutions.md', 'filter-concepts.md'])

# %%
p = re.compile(r'`(.+?)`')
docs_filters_candidates = {}
for filename, txt in docs_txt.items():
    docs_filters_candidates[filename] = p.findall(txt)

# %%
docs_filters_candidates
# Out:
# {'filter-works.md': ['filter',
#   'https://api.openalex.org/works?filter=publication\\_year:2020',
#   'publication_year',
#   '/works',
#   'Work',
#   'Work',
#   'host_venue',
#   'alternate_host_venues',
#   'primary_location',
#   'locations',
#   'host_venue',
#   'alternate_host_venues',
#   'authorships.author.id',
#   'author.id',
#   'authorships.author.orcid',
#   'author.orcid',
#   'authorships.countries',
#   'authorships.institutions.country_code',
#   'institutions.country_code',
#   'authorships.institutions.id',
#   'institutions.id',
#   'authorships.institutions.lineage',
#   'authorships.institutions.ror',
#   'institutions.ror',
#   'authorships.institutions.type',
#   'authorships.is_corresponding',
#   'is_corresponding',
#   'apc_list.value',
#   'apc_list.currency',
#   'apc_list.provenance',
#   'apc_list.value_usd',
#   'apc_paid.value',
#   'apc_paid.currency',
#   'apc_paid.provenance',
#   'apc_paid.value_usd',
#   'best_oa_location.is_accepted',
#   'best_oa_location.is_published',
#   'best_oa_location.license',
#   'best_oa_location.source.id',
#   'best_oa_location.source.is_in_doaj',
#   'best_oa_location.source.issn',
#   'best_oa_location.source.host_organization',
#   'best_oa_location.source.type',
#   'best_oa_location.version',
#   'cited_by_count',
#   'concepts.id',
#   'concept.id',
#   'concepts.wikidata',
#   'corresponding_author_ids',
#   'corresponding_institution_ids',
#   'countries_distinct_count',
#   'doi',
#   'grants.award_id',
#   'grants.funder',
#   'ids.pmcid',
#   'ids.pmid',
#   'pmid',
#   'ids.openalex',
#   'openalex',
#   'ids.mag',
#   'mag',
#   'institutions_distinct_count',
#   'is_paratext',
#   'is_retracted',
#   'language',
#   'locations.is_accepted',
#   'locations.is_oa',
#   'locations.is_published',
#   'locations.license',
#   'locations.source.id',
#   'locations.source.is_in_doaj',
#   'locations.source.issn',
#   'locations.source.host_organization',
#   'locations.source.type',
#   'locations.version',
#   'locations_count',
#   'open_access.any_repository_has_fulltext',
#   'open_access.is_oa',
#   'is_oa',
#   'open_access.oa_status',
#   'oa_status',
#   'primary_location.is_accepted',
#   'primary_location.is_oa',
#   'primary_location.is_published',
#   'primary_location.license',
#   'primary_location.source.id',
#   'primary_location.source.is_in_doaj',
#   'primary_location.source.issn',
#   'primary_location.source.host_organization',
#   'primary_location.source.type',
#   'primary_location.version',
#   'publication_year',
#   'publication_date',
#   'sustainable_development_goals.id',
#   'type',
#   'type_crossref',
#   'display_name',
#   '/works',
#   'Work',
#   'abstract.search',
#   'https://api.openalex.org/works?filter=abstract.search:artificial%20intelligence',
#   'authors_count',
#   'authorships',
#   'authors_count:>5',
#   'https://api.openalex.org/works?filter=authors\\_count:1',
#   'authorships.institutions.continent',
#   'institutions.continent',
#   'https://api.openalex.org/works?filter=authorships.institutions.continent:europe',
#   'authorships.institutions.is_global_south',
#   'institutions.is_global_south',
#   'true',
#   'false',
#   'https://api.openalex.org/works?filter=authorships.institutions.is\\_global\\_south:true',
#   'best_open_version',
#   'any',
#   'best_oa_location.version',
#   'submittedVersion',
#   'acceptedVersion',
#   'publishedVersion',
#   'acceptedOrPublished',
#   'best_oa_location.version',
#   'acceptedVersion',
#   'publishedVersion',
#   'published',
#   'best_oa_location.version',
#   'publishedVersion',
#   'best_oa_location',
#   'best_oa_location',
#   'https://api.openalex.org/works?filter=best_open_version:any',
#   '\\',
#   'cited_by',
#   'referenced_works',
#   'https://openalex.org/W2766808518',
#   'https://api.openalex.org/works?filter=cited_by:W2766808518',
#   'cites',
#   'referenced_works',
#   'https://openalex.org/W2741809807',
#   'https://api.openalex.org/works?filter=cites:W2741809807',
#   '\\',
#   'cited_by_count',
#   'concepts_count',
#   'concepts',
#   'https://api.openalex.org/works?filter=concepts\\_count:>2',
#   'default.search',
#   'search',
#   'display_name.search',
#   'title.search',
#   'display_name',
#   'https://api.openalex.org/works?filter=title.search:wombat',
#   'search',
#   'from_created_date',
#   'yyyy-mm-dd',
#   'created_date',
#   'https://api.openalex.org/works?filter=from_created_date:2023-01-12&api_key=myapikey',
#   '\\',
#   'from_publication_date',
#   'yyyy-mm-dd',
#   'publication_date',
#   'https://api.openalex.org/works?filter=from_publication_date:2001-03-14',
#   'from_created_date',
#   'from_updated_date',
#   'from_updated_date',
#   'updated_date',
#   'https://api.openalex.org/works?filter=from_updated_date:2023-01-12&api_key=myapikey',
#   'fulltext.search',
#   'https://api.openalex.org/works?filter=fulltext.search:climate%20change',
#   '\\',
#   'has_abstract',
#   'true',
#   'false',
#   'https://api.openalex.org/works?filter=has_abstract:true',
#   'has_doi',
#   'true',
#   'false',
#   'https://api.openalex.org/works?filter=has_doi:false',
#   '\\',
#   'has_oa_accepted_or_published_version',
#   'true',
#   'false',
#   'locations',
#   'is_oa',
#   'version',
#   'https://api.openalex.org/works?filter=has_oa_accepted_or_published_version:true',
#   'has_oa_submitted_version',
#   'true',
#   'false',
#   'locations',
#   'is_oa',
#   'version',
#   'https://api.openalex.org/works?filter=has_oa_submitted_version:true',
#   '\\',
#   'has_orcid',
#   'true',
#   'false',
#   'true',
#   'false',
#   'orcid',
#   'authorships.author',
#   'https://api.openalex.org/works?filter=has_orcid:true',
#   '\\',
#   'has_pmcid',
#   'true',
#   'false',
#   'pmcid',
#   'pmcid',
#   'https://api.openalex.org/works?filter=has_pmcid:true',
#   '\\',
#   'has_pmid',
#   'true',
#   'false',
#   'pmid',
#   'pmid',
#   'https://api.openalex.org/works?filter=has_pmid:true',
#   '\\',
#   'has_ngrams',
#   'true',
#   'false',
#   'fulltext.search',
#   'search',
#   'https://api.openalex.org/works?filter=has_ngrams:true',
#   'has_references',
#   'true',
#   'false',
#   'referenced_works',
#   'https://api.openalex.org/works?filter=has_references:true',
#   'journal',
#   'type: journal',
#   'primary_location.source',
#   'locations.source.host_institution_lineage',
#   'Institution',
#   'locations.source.host_organization_lineage',
#   'https://openalex.org/I205783295',
#   'host_organization_lineage',
#   'https://api.openalex.org/works?filter=locations.source.host_institution_lineage:https://openalex.org/I205783295',
#   'locations.source.publisher_lineage',
#   'Publisher',
#   'locations.source.host_organization_lineage',
#   'https://openalex.org/P4310320547',
#   'publisher_lineage',
#   'https://api.openalex.org/works?filter=locations.source.publisher_lineage:https://openalex.org/P4310320547',
#   'primary_location.source.has_issn',
#   'true',
#   'false',
#   'primary_location',
#   'https://api.openalex.org/works?filter=primary_location.source.has_issn:true',
#   'primary_location.source.publisher_lineage',
#   'Publisher',
#   'primary_location.source.host_organization_lineage',
#   'https://openalex.org/P4310320547',
#   'publisher_lineage',
#   'https://api.openalex.org/works?filter=primary_location.source.publisher_lineage:https://openalex.org/P4310320547',
#   'raw_affiliation_string.search',
#   'raw_affiliation_string',
#   'raw_affiliation_string',
#   'https://api.openalex.org/works?filter=raw_affiliation_string.search:department%20of%20political%20science%20university%20of%amsterdam',
#   '\\',
#   'related_to',
#   'related_works',
#   'https://api.openalex.org/works?filter=related_to:W2486144666',
#   'repository',
#   'type: repository',
#   'locations',
#   'https://openalex.org/S4306400393',
#   'https://api.openalex.org/works?filter=repository:S4306400393',
#   'https://api.openalex.org/works?filter=institutions.id:I27837315,repository:!S4306400393',
#   'group_by',
#   'https://api.openalex.org/works?filter=is_oa:true&group_by=repository',
#   'to_publication_date',
#   'yyyy-mm-dd',
#   'publication_date',
#   'https://api.openalex.org/works?filter=to_publication_date:2001-03-14',
#   '\\',
#   'version',
#   'publishedVersion',
#   'submittedVersion',
#   'acceptedVersion',
#   'null',
#   'locations',
#   'null',
#   '`[',
#   '](https://api.openalex.org/works?filter=version:publishedVersion)'],
#  'filter-authors.md': ['filter',
#   '/authors',
#   'Author',
#   'Author',
#   'cited_by_count',
#   'ids.openalex',
#   'openalex',
#   'last_known_institution.country_code',
#   'last_known_institution.id',
#   'last_known_institution.lineage',
#   'last_known_institution.ror',
#   'last_known_institution.type',
#   'orcid',
#   'scopus',
#   'summary_stats.2yr_mean_citedness',
#   'summary_stats.h_index',
#   'summary_stats.i10_index',
#   'works_count',
#   'x_concepts.id',
#   'concepts.id',
#   'concept.id',
#   'last_known_institution.display_name',
#   'institution.id',
#   'display_name',
#   'last_known_institution.id',
#   '/authors',
#   'Author',
#   'default.search',
#   'search',
#   'display_name.search',
#   'display_name',
#   'https://api.openalex.org/authors?filter=display_name.search:tupolev',
#   'has_orcid',
#   'true',
#   'false',
#   '`[',
#   'last_known_institution.continent',
#   'last_known_institution.is_global_south',
#   'true',
#   'false'],
#  'filter-sources.md': ['filter',
#   '/sources',
#   'Source',
#   'Source',
#   'apc_prices.currency',
#   'apc_prices.price',
#   'apc_usd',
#   'cited_by_count',
#   'country_code',
#   'host_organization',
#   'host_organization.id',
#   'host_organization_lineage',
#   'ids.openalex',
#   'openalex',
#   'is_in_doaj',
#   'is_oa',
#   'issn',
#   'publisher',
#   'host_organization_lineage',
#   'summary_stats.2yr_mean_citedness',
#   'summary_stats.h_index',
#   'summary_stats.i10_index',
#   'type',
#   'works_count',
#   'x_concepts.id',
#   'concepts.id',
#   'concept.id',
#   'host_organization.display_name',
#   'display_name',
#   'host_organization.id',
#   '/sources',
#   'Source',
#   'continent',
#   'default.search',
#   'search',
#   'display_name.search',
#   'display_name',
#   'https://api.openalex.org/sources?filter=display_name.search:Neurology',
#   'search',
#   'has_issn',
#   'true',
#   'false',
#   'https://api.openalex.org/sources?filter=has_issn:false',
#   'is_global_south',
#   'true',
#   'false'],
#  'filter-publishers.md': ['filter',
#   '/publishers',
#   'Publisher',
#   'Publisher',
#   'cited_by_count',
#   'country_codes',
#   'hierarchy_level',
#   'ids.openalex',
#   'openalex',
#   'ids.ror',
#   'ror',
#   'ids.wikidata',
#   'wikidata',
#   'lineage',
#   'parent_publisher',
#   'summary_stats.2yr_mean_citedness',
#   'summary_stats.h_index',
#   'summary_stats.i10_index',
#   'works_count',
#   '/publishers',
#   'Publisher',
#   'continent',
#   'default.search',
#   'search',
#   'display_name.search',
#   'display_name',
#   'https://api.openalex.org/publishers?filter=display_name.search:elsevier',
#   'search'],
#  'filter-funders.md': ['filter',
#   '/funders',
#   'Funder',
#   'Funder',
#   'cited_by_count',
#   'country_code',
#   'grants_count',
#   'ids.openalex',
#   'openalex',
#   'ids.ror',
#   'ror',
#   'ids.wikidata',
#   'wikidata',
#   'summary_stats.2yr_mean_citedness',
#   'summary_stats.h_index',
#   'summary_stats.i10_index',
#   'works_count',
#   '/funders',
#   'Funder',
#   'continent',
#   'https://api.openalex.org/funders?filter=continent:south\\_america',
#   'default.search',
#   'search',
#   'description.search',
#   'description',
#   'https://api.openalex.org/funders?filter=description.search:health',
#   'display_name.search',
#   'display_name',
#   'https://api.openalex.org/funders?filter=display_name.search:health',
#   'search',
#   'is_global_south',
#   'true',
#   'false'],
#  'filter-institutions.md': ['filter',
#   '/institutions',
#   'Institution',
#   'Institution',
#   'cited_by_count',
#   'country_code',
#   'openalex',
#   'lineage',
#   'Institution',
#   'repositories.host_organization',
#   'Institution',
#   'repositories.host_organization_lineage',
#   'Institution',
#   'repositories.id',
#   'Source',
#   'ror',
#   'summary_stats.2yr_mean_citedness',
#   'summary_stats.h_index',
#   'summary_stats.i10_index',
#   'type',
#   'works_count',
#   'x_concepts.id',
#   'concepts.id',
#   'concept.id',
#   '/institutions',
#   'Institution',
#   'continent',
#   'default.search',
#   'search',
#   'display_name.search',
#   'display_name',
#   'https://api.openalex.org/institutions?filter=display_name.search:technology',
#   'search',
#   'has_ror',
#   'true',
#   'false',
#   'https://api.openalex.org/institutions?filter=has_ror:false',
#   'is_global_south',
#   'true',
#   'false'],
#  'filter-concepts.md': ['filter',
#   'https://api.openalex.org/concepts?filter=level:0',
#   '/concepts',
#   'Concept',
#   'Concept',
#   'ancestors.id',
#   'cited_by_count',
#   'ids.openalex',
#   'openalex',
#   'level',
#   'summary_stats.2yr_mean_citedness',
#   'summary_stats.h_index',
#   'summary_stats.i10_index',
#   'works_count',
#   '/concepts',
#   'Concept',
#   'default.search',
#   'search',
#   'display_name.search',
#   'display_name',
#   'display_name',
#   'https://api.openalex.org/concepts?filter=display_name.search:electrodynamics',
#   'search',
#   'has_wikidata',
#   'true',
#   'false',
#   'https://api.openalex.org/concepts?filter=has_wikidata:false']}
