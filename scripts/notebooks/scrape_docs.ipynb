# %%
import os, sys, json
from pathlib import Path
import requests

# %%
import pandas as pd
import numpy as np

# %%
sys.path.append('..')

# %%
from markdown_edits import MarkdownDoc, MarkdownSection

# %%
entity_names = [
    "works",
    "authors",
    "sources",
    "institutions",
    "publishers",
    "funders",
    "concepts",
]

# %%
dirpath = Path('../../the-data/')
markdown_files = list(dirpath.rglob('*.md'))

# %%
markdown_docs = [MarkdownDoc(fp.read_text()) for fp in markdown_files]

# %%
ignore_docs = [
    'Geo',
    'Get N-grams',
    'Works with more than 100 authors are truncated',
    'Location attributes',
    'Authorship attributes',
]

# %%
def yield_attrs(doc, prefix):
    for sec in doc.sections:
        if 'attributes' in sec.title.lower():
            attrs_subdoc = MarkdownDoc(sec.content)
            attrs_subsections = [
                    MarkdownSection(sec, title, parent=attrs_subdoc, level=3)
                    for title, sec in attrs_subdoc.split_into_sections(attrs_subdoc.txt, level=3)
            ]
            # attrs = {}
            for sec in attrs_subsections:
                if sec.title:
                    title = sec.title.replace('\\', '').strip('`')
                    desc = sec.lines[2]
                    # attrs[f"source.{title}"] = desc
                    yield f"{prefix}.{title}", desc
    #         return attrs
    # return None

# %%
descriptions = {}
for doc in markdown_docs:
    try:
        sec = doc.sections[1]
        content_lines = [line for line in sec.content.split("\n") if line]
        desc = content_lines[0]
        title = ''.join([char for char in sec.title if char.isascii()])
        title = title.strip()
        if title in ignore_docs:
            print(f"ignoring {doc}")
            continue
        descriptions[title] = desc
        for attr_name, attr_desc in yield_attrs(doc, prefix=title.lower()):
            descriptions[attr_name] = attr_desc
    except IndexError:
        print(f"skipping {doc}")
# Out:
# skipping <class 'markdown_edits.MarkdownDoc'>(# Data overview\\The OpenAlex dataset describes sc...)
# ignoring <class 'markdown_edits.MarkdownDoc'>(---\description: Where things are in the world\---...)
# skipping <class 'markdown_edits.MarkdownDoc'>(# Continents\\Countries are mapped to continents u...)
# skipping <class 'markdown_edits.MarkdownDoc'>(# Regions\\### **Global South**\\The Global South ...)
# ignoring <class 'markdown_edits.MarkdownDoc'>(# Locations\\The locations online where a work liv...)
# ignoring <class 'markdown_edits.MarkdownDoc'>(# Authorships\\An authorship is a single author an...)
# ignoring <class 'markdown_edits.MarkdownDoc'>(---\description: N-grams are groups of sequential ...)
# ignoring <class 'markdown_edits.MarkdownDoc'>(# Limitations\\## Works with more than 100 authors...)

# %%
for k, v in descriptions.items():
    print(f"{k}: {v}")
# Out:
# Sources: Sources are where works are hosted.
# sources.abbreviated_title: An abbreviated title for this source.
# sources.alternate_titles: Alternate titles for this source, commonly abbreviations or translations of the source's canonical name.
# sources.apc_prices: Article processing charge (APC) information
# sources.apc_usd: The source's article processing charge in US Dollars
# sources.cited_by_count: The total number of works that cite a work hosted in this source.
# sources.country_code: The country that this source is associated with.
# sources.counts_by_year: The works count and cited-by count of this source for the last ten years, binned by year.
# sources.created_date: The date this source was created in the OpenAlex dataset.
# sources.display_name: The name of the source.
# sources.homepage_url: The starting page for navigating the contents of this source; the homepage for this source's website.
# sources.host_organization: The host organization for this source—either a publisher or an institution—as an OpenAlex ID.
# sources.host_organization_lineage: A list of OpenAlex IDs — See [`Publisher.lineage`](../publishers/publisher-object.md#lineage).
# sources.host_organization_name: The name of this source's host organization.
# sources.id: The OpenAlex ID for this source.
# sources.ids: All the external identifiers that we know about for this source.
# sources.is_in_doaj: Whether this is a journal listed in the Directory of Open Access Journals (DOAJ).
# sources.is_oa: Whether this is currently a fully-open-access source.
# sources.issn: The ISSNs used by this source.
# sources.issn_l: The ISSN-L identifying this source.
# sources.societies: Societies on whose behalf the source is published and maintained.
# sources.summary_stats: Citation metrics for this source.
# sources.type: The type of source, which will be one of: journal, repository, conference, or ebook platform.
# sources.updated_date: The last time anything in this source's data changed (any change at all, including increases in various counts).
# sources.works_api_url: A URL that will get you a list of all this source's works.
# sources.works_count: The number of works this source hosts.
# sources.x_concepts: The `Concepts` most frequently applied to works hosted by this source.
# Institutions: Institutions are universities and other organizations to which authors claim affiliations.
# institutions.associated_institutions: Institutions related to this one by one of three relationships: parent, child, or related.
# institutions.cited_by_count: The number of citations this institution has collected (or more formally, the total number of works that cite a work by an author affiliated with this institution).
# institutions.country_code: The country where this institution is located.
# institutions.counts_by_year: The works count and cited-by count of this institution for the last ten years, binned by year.
# institutions.created_date: The date this institution was created in the OpenAlex dataset.
# institutions.display_name: The primary name of the institution.
# institutions.display_name_acronyms: _List:_ Acronyms or initialisms that people sometimes use instead of the full [`display_name`](institution-object.md#display\_name).
# institutions.display_name_alternatives: Other names people may use for this institution.
# institutions.geo: A bunch of stuff we know about the location of this institution:
# institutions.homepage_url: The URL for institution's primary homepage.
# institutions.id: The OpenAlex ID for this institution.
# institutions.ids: All the external identifiers that we know about for this institution.
# institutions.image_thumbnail_url: URL where you can get a thumbnail image representing this institution.
# institutions.image_url: URL where you can get an image representing this institution.
# institutions.international: The institution's display name in different languages, derived from the wikipedia page for the institution in the given language.
# institutions.repositories: Repositories that this institutions hosts.
# institutions.roles: List of roles that this organization has, such as Institution, Funder, and Publisher.
# institutions.ror: The ROR ID for this institution.
# institutions.summary_stats: Citation metrics for this institution.
# institutions.type: The institution's primary type, one of: Education, Healthcare, Company, Archive, Nonprofit, Government, Facility, and Other
# institutions.updated_date: The last time anything in this institution's data changed (any change at all, including increases in various counts).
# institutions.works_api_url: A URL that will get you a list of all the works affiliated with this institution.
# institutions.works_count: The number of works coming out of this institution (or more formally, the number of works created by authors affiliated with this institution).
# institutions.x_concepts: The concepts most frequently applied to works affiliated with this institution.
# Concepts: Concepts are abstract ideas that works are about.
# concepts.ancestors: List of concepts that this concept descends from.
# concepts.cited_by_count: The number of citations to works that have been tagged with this concept.
# concepts.counts_by_year: The works count and cited-by count of this concept for the last ten years, binned by year.
# concepts.created_date: The date this concept was created in the OpenAlex dataset.
# concepts.description: A brief description of this concept.
# concepts.display_name: The English-language label of the concept.
# concepts.id: The OpenAlex ID for this concept.
# concepts.ids: All the external identifiers that we know about for this concept.
# concepts.image_thumbnail_url: URL where you can get a thumbnail image representing this concept.
# concepts.image_url: URL where you can get an image representing this concept, where available.
# concepts.international: This concept's display name in many languages, derived from article titles on each language's wikipedia.
# concepts.level: The level in the concept tree where this concept lives, from 0 (most general) to 5 (most specific).
# concepts.related_concepts: Concepts that are similar to this one.
# concepts.summary_stats: Citation metrics for this concept
# concepts.updated_date: The last time anything in this concept's data changed (any change at all, including increases in various counts).
# concepts.wikidata: The Wikidata ID for this concept.
# concepts.works_api_url: A URL that will get you a list of all the works tagged with this concept via the OpenAlex API.
# concepts.works_count: The number of works tagged with this concept.
# Publishers: Publishers are companies and organizations that distribute journal articles, books, and theses.
# publishers.alternate_titles: A list of alternate titles for this publisher.
# publishers.cited_by_count: The number of citations to works that are linked to this publisher through journals or other sources.
# publishers.country_codes: The countries where the publisher is primarily located
# publishers.counts_by_year: The works count and cited-by count of this publisher for the last ten years, binned by year.
# publishers.created_date: The date this publisher was created in the OpenAlex dataset.
# publishers.display_name: The primary name of the publisher.
# publishers.hierarchy_level: The hierarchy level for this publisher—level 0 means this publisher has no parent publisher, level 1 means one parent, and so on.
# publishers.id: The OpenAlex ID for this publisher.
# publishers.ids: All the external identifiers that we know about for this publisher.
# publishers.image_thumbnail_url: URL where you can get a thumbnail image representing this publisher.
# publishers.image_url: URL where you can get an image representing this publisher.
# publishers.lineage: A list of OpenAlex IDs that includes this publisher, as well as any parent publishers.
# publishers.parent_publisher: An OpenAlex ID linking to the direct parent of the publisher.
# publishers.roles: List of roles that this organization has, such as Institution, Funder, and Publisher.
# publishers.sources_api_url: A URL that will get you a list of all the sources published by this publisher.
# publishers.summary_stats: Citation metrics for this publisher.
# publishers.updated_date: The last time anything in this publisher's data changed (any change at all, including increases in various counts).
# publishers.works_count: The number of works published by this publisher.
# Funders: Funders are organizations that fund research.
# funders.alternate_titles: A list of alternate titles for this funder.
# funders.cited_by_count: The total number of works that cite a work linked to this funder.
# funders.country_code: The country where this funder is located.
# funders.counts_by_year: The works count and cited-by count of this funder for the last ten years, binned by year.
# funders.created_date: The date this funder was created in the OpenAlex dataset.
# funders.description: A short description of this funder, taken from Wikidata.
# funders.display_name: The primary name of the funder.
# funders.grants_count: The number of grants linked to this funder.
# funders.homepage_url: The URL for this funder's primary homepage.
# funders.id: The OpenAlex ID for this funder.
# funders.ids: All the external identifiers that we know about for this funder.
# funders.image_thumbnail_url: URL where you can get a thumbnail image representing this funder.
# funders.image_url: URL where you can get an image representing this funder.
# funders.roles: List of roles that this organization has, such as Institution, Funder, and Publisher.
# funders.summary_stats: Citation metrics for this funder
# funders.updated_date: The last time anything in this funder's data changed (any change at all, including increases in various counts).
# funders.works_count: The number of works linked to this funder.
# Works: Works are scholarly documents like journal articles, books, datasets, and theses.
# works.abstract_inverted_index: The abstract of the work, as an inverted index.
# works.alternate_host_venues` (deprecated): {% hint style="danger" %}
# works.authorships: List of authorships for this work, each representing an author and their institution(s).
# works.apc_list: The list-price APC (article processing charge) for this work.
# works.apc_paid: Information about the *paid* APC (article processing charge) for this work.
# works.best_oa_location: The best available open access location for this work.
# works.biblio: Old-timey bibliographic info for this work.
# works.cited_by_api_url: A URL that returns a list of works that cite this work.
# works.cited_by_count: The number of citations to this work.
# works.concepts: The concepts associated with this work.
# works.corresponding_author_ids: The corresponding authors for this work.
# works.corresponding_institution_ids: The institutions of the corresponding authors for this work.
# works.counts_by_year: The cited-by count of this work for the last ten years, binned by year.
# works.created_date: The date this work was created in the OpenAlex dataset.
# works.display_name: The title of this work.
# works.doi: The DOI (digital object identifier) for the work.
# works.grants: The grants that contributed funding to this work.
# works.host_venue` (deprecated): {% hint style="danger" %}
# works.id: The OpenAlex ID for this work.
# works.ids: All the external identifiers that we know about for this work.
# works.is_paratext: Whether this work is paratext—things like front cover, editorial board, or issue information.
# works.is_retracted: Whether this work has been retracted (as far as we are aware).
# works.language: The language of this work.
# works.locations: All of the unique places where this work lives.
# works.locations_count: Number of locations we have for this work.
# works.mesh: The MeSH tags for this work (only found in PubMed works).
# works.ngrams_url: A URL that will get you the groups of words and phrases (n-grams) that make up a work.
# works.open_access: Information about the access status of this work.
# works.primary_location: The the best (closest to the version of record) copy of this work.
# works.publication_date: The day when this work was published
# works.publication_year: The year this work was published.
# works.referenced_works: Works that this work cites.
# works.related_works: Works related to this work—recent papers with the most concepts in common.
# works.title: The title of this work.
# works.type: The type or genre of the work (such as "journal article," "book-chapter," or "dissertation").
# works.updated_date: The last time anything in this work's data changed (any change at all, including increases in various counts).
# works.is_oa: Whether this work can be read for free, without registration.
# works.license: The license applied to this work at this host.
# works.url: The URL where you can access this work.
# works.version: The version of the work—one of: "publishedVersion," "acceptedVersion," or "submittedVersion".
# Authors: Authors are people who create works.
# authors.cited_by_count: The total number of works that cite a work this author has created.
# authors.counts_by_year: The works count and cited-by count of this author for the last ten years, binned by year.
# authors.created_date: The date this author was created in the OpenAlex dataset.
# authors.display_name: The name of the author.
# authors.display_name_alternatives: Other ways that we've found this author's name displayed.
# authors.id: The OpenAlex ID for this author.
# authors.ids: All the external identifiers that we know about for this author.
# authors.last_known_institution: This author's last known institutional affiliation.
# authors.orcid: The ORCID ID for this author.
# authors.summary_stats: Citation metrics for this author
# authors.updated_date: The last time anything in this author's data changed (any change at all, including increases in various counts).
# authors.works_api_url: A URL that will get you a list of all this author's works via the OpenAlex API.
# authors.works_count: The number of Works that this author has created.
# authors.x_concepts: The concepts most frequently applied to works created by this author.

# %%
fields_from_api = {}
for entity_name in entity_names:
    filter_names = requests.get(f"https://api.openalex.org/{entity_name}/valid_fields").json()
    schema_names = requests.get(f"https://api.openalex.org/{entity_name}/flattened_schema").json()
    fields_from_api[entity_name] = {
        'filter_names': filter_names,
        'schema_names': schema_names,
    }

# %%
def get_description_or_parent(name):
    if name in descriptions:
        return name, descriptions[name]
    parts = name.split('.')
    if len(parts) > 1:
        for i in range(len(parts)):
            name = ".".join(parts[:-i-1])
            if name in descriptions:
                return name, descriptions[name]
    return None, None

# %%
data = {}
for entity_name, v in fields_from_api.items():
    for k, field_names in v.items():
        for field_name in field_names:
            this_name = f"{entity_name}.{field_name}"
            if this_name in data:
                data[this_name].update({
                    f'in_{k}': True
                })
            else:
                data[this_name] = {
                    'name': this_name,
                    'entity_name': entity_name,
                    f'in_{k}': True,
                }
                desc_key, desc = get_description_or_parent(this_name)
                if desc:
                    data[this_name].update({
                        'in_docs_scrape': True,
                        'docs_description': desc,
                        'docs_desc_key': desc_key,
                    })
df = pd.DataFrame(data.values())

# %%
df.to_csv('examine_docs_scrape.csv', index=False)

# %%
df
# Out:
#                           name entity_name in_filter_names in_docs_scrape  \
# 0        works.abstract.search       works            True            NaN
# 1      works.apc_list.currency       works            True           True
# 2    works.apc_list.provenance       works            True           True
# 3         works.apc_list.value       works            True           True
# 4     works.apc_list.value_usd       works            True           True
# ..                         ...         ...             ...            ...
# 423  concepts.related_concepts    concepts             NaN           True
# 424    concepts.counts_by_year    concepts             NaN           True
# 425     concepts.works_api_url    concepts             NaN           True
# 426      concepts.updated_date    concepts             NaN           True
# 427      concepts.created_date    concepts             NaN           True
#
#                                       docs_description  \
# 0                                                  NaN
# 1    The list-price APC (article processing charge)...
# 2    The list-price APC (article processing charge)...
# 3    The list-price APC (article processing charge)...
# 4    The list-price APC (article processing charge)...
# ..                                                 ...
# 423            Concepts that are similar to this one.
# 424  The works count and cited-by count of this con...
# 425  A URL that will get you a list of all the work...
# 426  The last time anything in this concept's data ...
# 427  The date this concept was created in the OpenA...
#
#                  docs_desc_key in_schema_names
# 0                          NaN             NaN
# 1               works.apc_list            True
# 2               works.apc_list            True
# 3               works.apc_list            True
# 4               works.apc_list            True
# ..                         ...             ...
# 423  concepts.related_concepts            True
# 424    concepts.counts_by_year            True
# 425     concepts.works_api_url            True
# 426      concepts.updated_date            True
# 427      concepts.created_date            True
#
# [428 rows x 7 columns]

# %%
glossary_sections = []
for entity_name, gdf in df.sort_values("entity_name").groupby("entity_name"):
    subset = gdf[['docs_desc_key', 'docs_description']].dropna().drop_duplicates().sort_values('docs_desc_key')
    this_section = f'## {entity_name.title()}\n\n'
    for _, row in subset.iterrows():
        subsection = f'### {row["docs_desc_key"].replace(f"{entity_name}.", "")}\n\n{row["docs_description"]}\n\n'
        this_section += subsection
    glossary_sections.append(this_section)

# %%
with Path("tmpglossary.md").open("w") as outf:
    for glossary_section in glossary_sections:
        outf.write(glossary_section)
        outf.write("\n")
